# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("./Zillow_Pittsburgh_forSale_08-20.xlsx")

# %%
from bs4 import BeautifulSoup
import requests

# %%
r = requests.get("https://api.census.gov/data/2016/acs/acs5/subject/variables.html")

# %%
data = r.text

# %%
soup = BeautifulSoup(data)
# Out:
# /Users/jimzedli/anaconda3/lib/python3.5/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/jimzedli/anaconda3/lib/python3.5/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
import json

# %%
json.loads("total_pop.json")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-9c12dc0689b8> in <module>()
# ----> 1 json.loads("total_pop.json")
#
# ~/anaconda3/lib/python3.5/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     317             parse_int is None and parse_float is None and
#     318             parse_constant is None and object_pairs_hook is None and not kw):
# --> 319         return _default_decoder.decode(s)
#     320     if cls is None:
#     321         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.5/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/anaconda3/lib/python3.5/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
import pandas
pandas.read_csv("acs_income.csv")
# Out:
#      Unnamed: 0                                               NAME  state  \
# 0             1   Census Tract 103, Allegheny County, Pennsylvania     42
# 1             2   Census Tract 201, Allegheny County, Pennsylvania     42
# 2             3   Census Tract 203, Allegheny County, Pennsylvania     42
# 3             4   Census Tract 305, Allegheny County, Pennsylvania     42
# 4             5   Census Tract 402, Allegheny County, Pennsylvania     42
# 5             6   Census Tract 404, Allegheny County, Pennsylvania     42
# 6             7   Census Tract 405, Allegheny County, Pennsylvania     42
# 7             8   Census Tract 406, Allegheny County, Pennsylvania     42
# 8             9   Census Tract 409, Allegheny County, Pennsylvania     42
# 9            10   Census Tract 501, Allegheny County, Pennsylvania     42
# 10           11   Census Tract 506, Allegheny County, Pennsylvania     42
# 11           12   Census Tract 509, Allegheny County, Pennsylvania     42
# 12           13   Census Tract 510, Allegheny County, Pennsylvania     42
# 13           14   Census Tract 511, Allegheny County, Pennsylvania     42
# 14           15   Census Tract 603, Allegheny County, Pennsylvania     42
# 15           16   Census Tract 605, Allegheny County, Pennsylvania     42
# 16           17   Census Tract 703, Allegheny County, Pennsylvania     42
# 17           18   Census Tract 705, Allegheny County, Pennsylvania     42
# 18           19   Census Tract 706, Allegheny County, Pennsylvania     42
# 19           20   Census Tract 708, Allegheny County, Pennsylvania     42
# 20           21   Census Tract 709, Allegheny County, Pennsylvania     42
# 21           22   Census Tract 802, Allegheny County, Pennsylvania     42
# 22           23   Census Tract 804, Allegheny County, Pennsylvania     42
# 23           24   Census Tract 806, Allegheny County, Pennsylvania     42
# 24           25   Census Tract 807, Allegheny County, Pennsylvania     42
# 25           26   Census Tract 809, Allegheny County, Pennsylvania     42
# 26           27   Census Tract 901, Allegheny County, Pennsylvania     42
# 27           28   Census Tract 902, Allegheny County, Pennsylvania     42
# 11        3   50900        14281           NaN         3759           NaN
# 12        3   51000        16373           NaN         2685           NaN
# 13        3   51100        20313           NaN        12623           NaN
# 14        3   60300        51964           NaN         4711           NaN
# 15        3   60500        36786           NaN         7838           NaN
# 16        3   70300        56136           NaN        14029           NaN
# 17        3   70500        50838           NaN         3155           NaN
# 18        3   70600        48719           NaN         5135           NaN
# 19        3   70800        50972           NaN         3820           NaN
# 20        3   70900        30359           NaN         7779           NaN
# 21        3   80200        40784           NaN         4988           NaN
# 22        3   80400        32750           NaN         5706           NaN
# 23        3   80600        55611           NaN         7627           NaN
# 24        3   80700        35057           NaN        11905           NaN
# 25        3   80900        51458           NaN         8168           NaN
# 26        3   90100        52708           NaN         8314           NaN
# 27        3   90200        53115           NaN         7560           NaN
# 28        3   90300        37372           NaN         7401           NaN
# 29        3  100500        46308           NaN         6732           NaN
# ..      ...     ...          ...           ...          ...           ...
# 372       3  562500        29375           NaN        10961           NaN
# 373       3  562600        32869           NaN        11910           NaN
# 374       3  562700        37386           NaN        11583           NaN
# 375       3  562800        42946           NaN         9798           NaN
# 376       3  562900        36750           NaN         7133           NaN
# 377       3  563000        61318           NaN         4865           NaN
# 378       3  563100        53184           NaN         4300           NaN
# 379       3  563200        30394           NaN         5970           NaN
# 380       3  563300       153750           NaN        25253           NaN
# 381       3  563800        74345           NaN         6617           NaN
# 382       3  563900        51555           NaN         7647           NaN
# 383       3  564000        64505           NaN        11024           NaN
# 384       3  564100       131875           NaN        12866           NaN
# 385       3  564200        57857           NaN         9715           NaN
# 386       3  564400        44298           NaN         5139           NaN
# 387       3  564500        64456           NaN         9355           NaN
# 388       3  980000       101917           NaN         8929           NaN
# 389       3  980100   -666666666           NaN   -222222222           NaN
# 390       3  980300   -666666666           NaN   -222222222           NaN
# 391       3  980400   -666666666           NaN   -222222222           NaN
# 392       3  980500   -666666666           NaN   -222222222           NaN
# 393       3  980600   -666666666           NaN   -222222222           NaN
# 394       3  980700   -666666666           NaN   -222222222           NaN
# 395       3  980800   -666666666           NaN   -222222222           NaN
# 396       3  980900   -666666666           NaN   -222222222           NaN
# 397       3  981000   -666666666           NaN   -222222222           NaN
# 398       3  981100   -666666666           NaN   -222222222           NaN
# 399       3  981200   -666666666           NaN   -222222222           NaN
# 400       3  981800        18750           NaN         1360           NaN
# 401       3  982200        16250           NaN         7959           NaN
#
# [402 rows x 9 columns]

# %%
df = pandas.read_json("allegheny_county_census_tracts_2016.geojson")

# %%
df.columns
# Out:
# Index(['features', 'type'], dtype='object')

# %%
df['features'][0]['properties']['TRACTCE']
# Out:
# '050900'
